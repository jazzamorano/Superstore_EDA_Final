# %% [markdown]
# #Superstore EDA Final
# *   Cleaning steps, resolving errors, and appropiate data types
# *   Appropiate descriptive statistics and visualizations
# *   Ensure all codes are performed
# *   Codes clearly
#
# Jazmin Zamorano

# %% [markdown]
# ## Visualization data

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Descriptive Analytics 01/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx')

# %%
data = df['Ship Mode'].value_counts()
data.plot.barh();

# %% [markdown]
# In here you can see that the ship mode values are being expressed in a horizontal graph from less to more based on quantity.

# %%
data = df['Segment'].value_counts()
data.plot.barh();

# %%
data = df['Region'].value_counts()
data.plot.barh();

# %% [markdown]
# In here you can see that the region value counts are being expressed from least to more in quantity. Having central asia as the least and Western Europe as the most.

# %%
data = df['Market'].value_counts()
data.plot.barh();

# %%
data = df['Category'].value_counts()
data.plot.barh();

# %%
data = df['Sub-Category'].value_counts()
data.plot.barh();

# %%
data = df['Order Priority'].value_counts()
data.plot.barh();

# %%
data = df['Ship Mode'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['Segment'].value_counts(ascending=True)
data.plot.barh();

# %% [markdown]
# Here the graph is showing information about the segments, which are: consumer,corporate, and home office. Data is shown from more to less(ascending values).

# %%
data = df['Region'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['Market'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['Category'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['Order Priority'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['Ship Mode'].value_counts(ascending=True)
data
# Out:
# Ship Mode
# Same Day           2701
# First Class        7505
# Second Class      10309
# Standard Class    30775
# Name: count, dtype: int64

# %%
data = df['Segment'].value_counts(ascending=True)
data
# Out:
# Segment
# Home Office     9343
# Corporate      15429
# Consumer       26518
# Name: count, dtype: int64

# %%
data = df['Region'].value_counts(ascending=True)
data
# Out:
# Region
# Central Asia          217
# Canada                384
# Southern Africa       478
# Central Africa        643
# Eastern Africa        728
# North Africa         1278
# Western Africa       1460
# Eastern Europe       1529
# Southern US          1620
# Caribbean            1690
# Southern Europe      2113
# Northern Europe      2204
# Central US           2323
# Eastern Asia         2374
# Western Asia         2440
# Southern Asia        2655
# Eastern US           2848
# South America        2988
# Southeastern Asia    3129
# Western US           3203
# Oceania              3487
# Central America      5616
# Western Europe       5883
# Name: count, dtype: int64

# %%
data = df['Market'].value_counts(ascending=True)
data
# Out:
# Market
# Africa           4587
# LATAM           10294
# USCA            10378
# Europe          11729
# Asia Pacific    14302
# Name: count, dtype: int64

# %% [markdown]
# In here we can see that data is presented in form of a table. Showing the values of the different markets from different continents in ascending values. Havinf Africa as the least, and Asia Pacific as the most.

# %%
data = df['Category'].value_counts(ascending=True)
data
# Out:
# Category
# Furniture           9860
# Technology         10141
# Office Supplies    31289
# Name: count, dtype: int64

# %%
data = df['Sub-Category'].value_counts(ascending=True)
data
# Out:
# Sub-Category
# Tables          861
# Machines       1486
# Appliances     1742
# Copiers        2223
# Envelopes      2387
# Supplies       2407
# Bookcases      2411
# Fasteners      2601
# Labels         2601
# Accessories    3075
# Furnishings    3154
# Phones         3357
# Chairs         3434
# Paper          3492
# Art            4864
# Storage        5049
# Binders        6146
# Name: count, dtype: int64

# %%
data = df['Order Priority'].value_counts(ascending=True)
data
# Out:
# Order Priority
# Low          2424
# Critical     3932
# High        15501
# Medium      29433
# Name: count, dtype: int64

# %%
data = df['Ship Mode'].value_counts(normalize=True)
data
# Out:
# Ship Mode
# Standard Class    0.600019
# Second Class      0.200994
# First Class       0.146325
# Same Day          0.052661
# Name: proportion, dtype: float64

# %%
data = df['Segment'].value_counts(normalize=True)
data
# Out:
# Segment
# Consumer       0.517021
# Corporate      0.300819
# Home Office    0.182160
# Name: proportion, dtype: float64

# %% [markdown]
# In here we can see that data is presented in a form of table. Having the data normalized, so in decimal numbers. Having consumers as the most and home office as the least (smallest value).

# %%
data = df['Region'].value_counts(normalize=True)
data
# Out:
# Region
# Western Europe       0.114701
# Central America      0.109495
# Oceania              0.067986
# Western US           0.062449
# Southeastern Asia    0.061006
# South America        0.058257
# Eastern US           0.055527
# Southern Asia        0.051764
# Western Asia         0.047573
# Eastern Asia         0.046286
# Central US           0.045291
# Northern Europe      0.042971
# Southern Europe      0.041197
# Caribbean            0.032950
# Southern US          0.031585
# Eastern Europe       0.029811
# Western Africa       0.028466
# North Africa         0.024917
# Eastern Africa       0.014194
# Central Africa       0.012537
# Southern Africa      0.009320
# Canada               0.007487
# Central Asia         0.004231
# Name: proportion, dtype: float64

# %%
data = df['Market'].value_counts(normalize=True)
data
# Out:
# Market
# Asia Pacific    0.278846
# Europe          0.228680
# USCA            0.202340
# LATAM           0.200702
# Africa          0.089433
# Name: proportion, dtype: float64

# %%
data = df['Category'].value_counts(normalize=True)
data
# Out:
# Category
# Office Supplies    0.610041
# Technology         0.197719
# Furniture          0.192240
# Name: proportion, dtype: float64

# %%
data = df['Sub-Category'].value_counts(normalize=True)
data
# Out:
# Sub-Category
# Binders        0.119828
# Storage        0.098440
# Art            0.094833
# Paper          0.068083
# Chairs         0.066953
# Phones         0.065451
# Furnishings    0.061493
# Accessories    0.059953
# Labels         0.050712
# Fasteners      0.050712
# Bookcases      0.047007
# Supplies       0.046929
# Envelopes      0.046539
# Copiers        0.043342
# Appliances     0.033964
# Machines       0.028973
# Tables         0.016787
# Name: proportion, dtype: float64

# %%
data = df['Order Priority'].value_counts(normalize=True)
data
# Out:
# Order Priority
# Medium      0.573855
# High        0.302223
# Critical    0.076662
# Low         0.047261
# Name: proportion, dtype: float64

# %%
data = df['Ship Mode'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %%
data = df['Segment'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %%
data = df['Region'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %% [markdown]
# Here information is shown in ascending and normalize values. The data is showing information about the different regions.The most is  Western Europe and the least Central Asia. It is showing 23 different regions.

# %%
data = df['Market'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %%
data = df['Category'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %%
data = df['Sub-Category'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %%
data = df['Order Priority'].value_counts(ascending=True,normalize=True)
data.plot.barh();

# %%
data = df['Segment'].value_counts()
data
# Out:
# Segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: count, dtype: int64

# %%
data = df['Region'].value_counts()
data
# Out:
# Region
# Western Europe       5883
# Central America      5616
# Oceania              3487
# Western US           3203
# Southeastern Asia    3129
# South America        2988
# Eastern US           2848
# Southern Asia        2655
# Western Asia         2440
# Eastern Asia         2374
# Central US           2323
# Northern Europe      2204
# Southern Europe      2113
# Caribbean            1690
# Southern US          1620
# Eastern Europe       1529
# Western Africa       1460
# North Africa         1278
# Eastern Africa        728
# Central Africa        643
# Southern Africa       478
# Canada                384
# Central Asia          217
# Name: count, dtype: int64

# %%
data = df['Market'].value_counts()
data
# Out:
# Market
# Asia Pacific    14302
# Europe          11729
# USCA            10378
# LATAM           10294
# Africa           4587
# Name: count, dtype: int64

# %% [markdown]
# Here market data is shown in form of a table. Having only 5 different markets. Asis Pacific as the greatest and Africa as the least with 4587.

# %%
data = df['Category'].value_counts()
data
# Out:
# Category
# Office Supplies    31289
# Technology         10141
# Furniture           9860
# Name: count, dtype: int64

# %%
data = df['Sub-Category'].value_counts()
data
# Out:
# Sub-Category
# Binders        6146
# Storage        5049
# Art            4864
# Paper          3492
# Chairs         3434
# Phones         3357
# Furnishings    3154
# Accessories    3075
# Labels         2601
# Fasteners      2601
# Bookcases      2411
# Supplies       2407
# Envelopes      2387
# Copiers        2223
# Appliances     1742
# Machines       1486
# Tables          861
# Name: count, dtype: int64

# %%
data = df['Order Priority'].value_counts()
data
# Out:
# Order Priority
# Medium      29433
# High        15501
# Critical     3932
# Low          2424
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaning Steps

# %%
import pandas as pd

# %%
run_times = pd.read_excel('/content/drive/MyDrive/Descriptive Analytics 01/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx')

# %%
run_times
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [51290 rows x 24 columns]

# %%
run_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(15)
# memory usage: 9.4+ MB

# %%
run_times.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1   22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2   48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3   11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4   22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
#
#    Customer ID    Customer Name      Segment  Postal Code         City  ...  \
# 0    TB-112803  Toby Braunhardt     Consumer          NaN  Constantine  ...
# 1    JH-159857      Joseph Holt     Consumer          NaN  Wagga Wagga  ...
# 2     AT-73557    Annie Thurman     Consumer          NaN     Budapest  ...
# 3  EM-14140124     Eugene Moren  Home Office          NaN    Stockholm  ...
# 4    JH-159857      Joseph Holt     Consumer          NaN  Wagga Wagga  ...
#
#     Product ID         Category Sub-Category                 Product Name  \
# 0  OFF-ST-6261  Office Supplies      Storage          Tenex Lockers, Blue
# 1  OFF-SU-3002  Office Supplies     Supplies     Acme Trimmer, High Speed
# 2  OFF-ST-6230  Office Supplies      Storage      Tenex Box, Single Width
# 3  OFF-PA-4177  Office Supplies        Paper  Enermax Note Cards, Premium
# 4  FUR-FU-4075        Furniture  Furnishings   Eldon Light Bulb, Duo Pack
#
#      Sales Quantity Discount   Profit  Shipping Cost  Order Priority
# 0  408.300        2      0.0  106.140          35.46          Medium
# 1  120.366        3      0.1   36.036           9.72          Medium
# 2   66.120        4      0.0   29.640           8.17            High
# 3   44.865        3      0.5  -26.055           4.82            High
# 4  113.670        5      0.1   37.770           4.70          Medium
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Converting Data Types

# %%
import pandas as pd

# %%
pd.read_excel('/content/drive/MyDrive/Descriptive Analytics 01/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx')
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [51290 rows x 24 columns]

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [51290 rows x 24 columns]

# %% [markdown]
# ### Missing Data
#
# There are various ways to represent missing data in python:
# -Np.NaN
# -pd.NA
# -None

# %%
df.isna().any()
# Out:
# Row ID            False
# Order ID          False
# Order Date        False
# Ship Date         False
# Ship Mode         False
# Customer ID       False
# Customer Name     False
# Segment           False
# Postal Code        True
# City              False
# State             False
# Country           False
# Region            False
# Market            False
# Product ID        False
# Category          False
# Sub-Category      False
# Product Name      False
# Sales             False
# Quantity          False
# Discount          False
# Profit            False
# Shipping Cost     False
# Order Priority    False
# dtype: bool

# %%
df.isna().sum().sum()
# Out:
# 41296

# %%
run_times.Profit.astype('int')
# Out:
# 0        106
# 1         36
# 2         29
# 3        -26
# 4         37
#         ...
# 51285      0
# 51286     25
# 51287     12
# 51288      0
# 51289      0
# Name: Profit, Length: 51290, dtype: int64

# %% [markdown]
# ### Missing Data

# %%
df= pd.read_excel('/content/drive/MyDrive/Descriptive Analytics 01/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx')

# %%
df.tail()
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 51285   47594   MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700  IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857  MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143  MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852  MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#       Customer ID     Customer Name      Segment  Postal Code     City  ...  \
# 51285   LP-709586         Liz Preis     Consumer          NaN   Agadir  ...
# 51286  KM-1622527      Kalyca Meade    Corporate          NaN  Shantou  ...
# 51287  CM-1219093  Charlotte Melton     Consumer          NaN  Managua  ...
# 51288  JB-1604582     Julia Barnett  Home Office          NaN  Reynosa  ...
# 51289  TD-2099582     Tamara Dahlen     Consumer          NaN   Juárez  ...
#
#         Product ID         Category Sub-Category  \
# 51285  OFF-BI-6397  Office Supplies      Binders
# 51286  OFF-PA-4002  Office Supplies        Paper
# 51287  OFF-LA-4637  Office Supplies       Labels
# 51288  OFF-LA-5388  Office Supplies       Labels
# 51289  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name  Sales Quantity Discount  \
# 51285   Wilson Jones Hole Reinforcements, Clear   3.99        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11  79.47        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set  26.40        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable  16.74        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical   7.12        1      0.0
#
#       Profit  Shipping Cost  Order Priority
# 51285   0.42          1.490          Medium
# 51286  25.38          1.410          Medium
# 51287  12.36          1.350          Medium
# 51288   0.66          1.324          Medium
# 51289   0.56          1.199          Medium
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(15)
# memory usage: 9.4+ MB

# %%
df.value_counts()
# Out:
# Row ID  Order ID                  Order Date  Ship Date   Ship Mode       Customer ID   Customer Name     Segment      Postal Code  City         State          Country        Region       Market  Product ID   Category         Sub-Category  Product Name                                                               Sales    Quantity  Discount  Profit     Shipping Cost  Order Priority
# 31297   CA-2014-CG12520140-41952  2014-11-09  2014-11-12  Second Class    CG-125201408  Claire Gute       Consumer     42420.0      Henderson    Kentucky       United States  Southern US  USCA    FUR-BO-3645  Furniture        Bookcases     Bush Somerset Collection Bookcase                                          261.960  2         0.0        41.9136   54.10          Critical          1
# 37962   CA-2014-JS15880140-41835  2014-07-15  2014-07-19  Second Class    JS-158801402  John Stevenson    Consumer     75061.0      Irving       Texas          United States  Central US   USCA    OFF-PA-6466  Office Supplies  Paper         Xerox 1914                                                                 219.840  5         0.2        79.6920   35.96          High              1
# 37955   CA-2015-KM16375140-42056  2015-02-21  2015-02-28  Standard Class  KM-163751404  Katherine Murray  Home Office  85234.0      Gilbert      Arizona        United States  Western US   USCA    FUR-FU-4759  Furniture        Furnishings   Howard Miller 13" Diameter Pewter Finish Round Wall Clock                  68.704   2         0.2        16.3172   7.59           Low               1
# 37956   CA-2015-KM16375140-42056  2015-02-21  2015-02-28  Standard Class  KM-163751404  Katherine Murray  Home Office  85234.0      Gilbert      Arizona        United States  Western US   USCA    FUR-TA-4943  Furniture        Tables        KI Adjustable-Height Table                                                 386.910  9         0.5       -185.7168  44.06          Low               1
# 37957   CA-2013-DB13405140-41494  2013-08-08  2013-08-10  Second Class    DB-134051406  Denny Blanton     Consumer     1841.0       Lawrence     Massachusetts  United States  Eastern US   USCA    OFF-AR-3522  Office Supplies  Art           Boston 1827 Commercial Additional Cutter, Drive Gear & Gear Rack for 1606  39.660   2         0.0        11.8980   8.62           Critical          1
#                                                                                                                                                                                                                                                                                                                                                                                                    ..
# 34629   CA-2015-GM14455140-42353  2015-12-15  2015-12-21  Standard Class  GM-144551402  Gary Mitchum      Home Office  60653.0      Chicago      Illinois       United States  Central US   USCA    TEC-PH-5828  Technology       Phones        Samsung HM1900 Bluetooth Headset                                           52.680   3         0.2        19.7550   1.36           Medium            1
# 34630   CA-2015-GM14455140-42353  2015-12-15  2015-12-21  Standard Class  GM-144551402  Gary Mitchum      Home Office  60653.0      Chicago      Illinois       United States  Central US   USCA    FUR-FU-5172  Furniture        Furnishings   Master Caster Door Stop, Gray                                              2.032    1         0.6       -1.3208    1.10           Medium            1
# 34631   US-2015-PR18880140-42238  2015-08-22  2015-08-23  First Class     PR-188801404  Patrick Ryan      Consumer     94601.0      Oakland      California     United States  Western US   USCA    OFF-AR-5315  Office Supplies  Art           Newell 336                                                                 17.120   4         0.0        4.9648    2.36           Medium            1
# 34632   US-2015-PR18880140-42238  2015-08-22  2015-08-23  First Class     PR-188801404  Patrick Ryan      Consumer     94601.0      Oakland      California     United States  Western US   USCA    TEC-PH-3782  Technology       Phones        Cisco 8x8 Inc. 6753i IP Business Phone System                              431.968  4         0.2        37.7972   37.76          Medium            1
# 41290   CA-2015-CC12220140-42129  2015-05-05  2015-05-10  Second Class    CC-122201404  Chris Cortes      Consumer     92683.0      Westminster  California     United States  Western US   USCA    OFF-AP-2889  Office Supplies  Appliances    Acco 7-Outlet Masterpiece Power Center, Wihtout Fax/Phone Line Protection  243.160  2         0.0        72.9480   25.33          Medium            1
# Name: count, Length: 9994, dtype: int64

# %%
df.isna()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51285   False     False       False      False      False        False
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment  Postal Code   City  ...  Product ID  Category  \
# 0              False    False         True  False  ...       False     False
# 1              False    False         True  False  ...       False     False
# 2              False    False         True  False  ...       False     False
# 3              False    False         True  False  ...       False     False
# 4              False    False         True  False  ...       False     False
# ...              ...      ...          ...    ...  ...         ...       ...
# 51285          False    False         True  False  ...       False     False
# 51286          False    False         True  False  ...       False     False
# 51287          False    False         True  False  ...       False     False
# 51288          False    False         True  False  ...       False     False
# 51289          False    False         True  False  ...       False     False
#
#        Sub-Category  Product Name  Sales  Quantity  Discount  Profit  \
# 0             False         False  False     False     False   False
# 1             False         False  False     False     False   False
# 2             False         False  False     False     False   False
# 3             False         False  False     False     False   False
# 4             False         False  False     False     False   False
# ...             ...           ...    ...       ...       ...     ...
# 51285         False         False  False     False     False   False
# 51286         False         False  False     False     False   False
# 51287         False         False  False     False     False   False
# 51288         False         False  False     False     False   False
# 51289         False         False  False     False     False   False
#
#        Shipping Cost  Order Priority
# 0              False           False
# 1              False           False
# 2              False           False
# 3              False           False
# 4              False           False
# ...              ...             ...
# 51285          False           False
# 51286          False           False
# 51287          False           False
# 51288          False           False
# 51289          False           False
#
# [51290 rows x 24 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [41296 rows x 24 columns]

# %% [markdown]
# ### Handling Missing Data

# %%
 df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [51290 rows x 24 columns]

# %%
df["Profit"].count()
# Out:
# 51290

# %% [markdown]
# ### Removing Missing Data

# %%
df.dropna()
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 29      39277  CA-2012-DP13000140-40912 2012-01-04 2012-01-08  Standard Class
# 47      32037  CA-2012-PO19195140-40913 2012-01-05 2012-01-09  Standard Class
# 48      32036  CA-2012-PO19195140-40913 2012-01-05 2012-01-09  Standard Class
# 49      32038  CA-2012-PO19195140-40913 2012-01-05 2012-01-09  Standard Class
# 55      33056  CA-2012-MB18085140-40914 2012-01-06 2012-01-13  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51253   32593  CA-2015-EB13975140-42369 2015-12-31 2016-01-04  Standard Class
# 51260   36388  CA-2015-JM15580140-42369 2015-12-31 2016-01-04  Standard Class
# 51281   32203  CA-2015-PO18865140-42369 2015-12-31 2016-01-04  Standard Class
# 51282   32204  CA-2015-PO18865140-42369 2015-12-31 2016-01-04  Standard Class
# 51283   32205  CA-2015-PO18865140-42369 2015-12-31 2016-01-04  Standard Class
#
#         Customer ID      Customer Name      Segment  Postal Code  \
# 29     DP-130001402      Darren Powers     Consumer      77095.0
# 47     PO-191951402      Phillina Ober  Home Office      60540.0
# 48     PO-191951402      Phillina Ober  Home Office      60540.0
# 49     PO-191951402      Phillina Ober  Home Office      60540.0
# 55     MB-180851406         Mick Brown     Consumer      19143.0
# ...             ...                ...          ...          ...
# 51253  EB-139751404         Erica Bern    Corporate      94533.0
# 51260  JM-155801404      Jill Matthias     Consumer      80538.0
# 51281  PO-188651406  Patrick O'Donnell     Consumer      10009.0
# 51282  PO-188651406  Patrick O'Donnell     Consumer      10009.0
# 51283  PO-188651406  Patrick O'Donnell     Consumer      10009.0
#
#                 City  ...   Product ID         Category Sub-Category  \
# 29           Houston  ...  OFF-PA-5229  Office Supplies        Paper
# 47        Naperville  ...  OFF-ST-5754  Office Supplies      Storage
# 48        Naperville  ...  OFF-LA-3229  Office Supplies       Labels
# 49        Naperville  ...  OFF-BI-4365  Office Supplies      Binders
# 55      Philadelphia  ...  OFF-AR-3283  Office Supplies          Art
# ...              ...  ...          ...              ...          ...
# 51253      Fairfield  ...  OFF-BI-3741  Office Supplies      Binders
# 51260       Loveland  ...  OFF-FA-3330  Office Supplies    Fasteners
# 51281  New York City  ...  FUR-BO-3651        Furniture    Bookcases
# 51282  New York City  ...  TEC-PH-4388       Technology       Phones
# 51283  New York City  ...  OFF-BI-6409  Office Supplies      Binders
#
#                                             Product Name    Sales Quantity  \
# 29     Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 47                         SAFCO Boltless Steel Shelving  272.736        3
# 48                                             Avery 508   11.784        3
# 49            GBC Standard Plastic Binding Systems Combs    3.540        2
# 55     Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536        3
# ...                                                  ...      ...      ...
# 51253    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904        2
# 51260                                Bagged Rubber Bands    3.024        3
# 51281  Bush Westfield Collection Bookcases, Fully Ass...  323.136        4
# 51282                          Gear Head AU3700S Headset   90.930        7
# 51283               Wilson Jones Legal Size Ring Binders   52.776        3
#
#       Discount   Profit  Shipping Cost  Order Priority
# 29         0.2   5.5512           1.82            High
# 47         0.2 -64.7748          13.59            High
# 48         0.2   4.2717           1.99            High
# 49         0.8  -5.4870           1.55            High
# 55         0.2   4.8840           1.85             Low
# ...        ...      ...            ...             ...
# 51253      0.2   4.5188           1.89          Medium
# 51260      0.2  -0.6048           1.17          Medium
# 51281      0.2  12.1176          38.27            High
# 51282      0.0   2.7279           9.67            High
# 51283      0.2  19.7910           7.21            High
#
# [9994 rows x 24 columns]

# %%
df.dropna(how="all")
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [51290 rows x 24 columns]

# %%
df.dropna(subset=["Segment"])
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [51290 rows x 24 columns]

# %%
df[df.isna().any(axis=1)].dropna(subset=['Segment', 'Profit'])
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [41296 rows x 24 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [41296 rows x 24 columns]

# %%
df.Profit.mean()
# Out:
# 28.61098247767596

# %% [markdown]
# ### Resolving Missing Data

# %%
df[df.isna().any(axis=1)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1       22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2       48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3       11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4       22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
# 51286   27700   IN-2015-KM1622527-42369 2015-12-31 2016-01-07  Standard Class
# 51287    8857   MX-2015-CM1219093-42369 2015-12-31 2016-01-02    Second Class
# 51288    2143   MX-2015-JB1604582-42369 2015-12-31 2016-01-04  Standard Class
# 51289    6852   MX-2015-TD2099582-42369 2015-12-31 2016-01-06  Standard Class
#
#        Customer ID     Customer Name      Segment  Postal Code         City  \
# 0        TB-112803   Toby Braunhardt     Consumer          NaN  Constantine
# 1        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# 2         AT-73557     Annie Thurman     Consumer          NaN     Budapest
# 3      EM-14140124      Eugene Moren  Home Office          NaN    Stockholm
# 4        JH-159857       Joseph Holt     Consumer          NaN  Wagga Wagga
# ...            ...               ...          ...          ...          ...
# 51285    LP-709586         Liz Preis     Consumer          NaN       Agadir
# 51286   KM-1622527      Kalyca Meade    Corporate          NaN      Shantou
# 51287   CM-1219093  Charlotte Melton     Consumer          NaN      Managua
# 51288   JB-1604582     Julia Barnett  Home Office          NaN      Reynosa
# 51289   TD-2099582     Tamara Dahlen     Consumer          NaN       Juárez
#
#        ...   Product ID         Category Sub-Category  \
# 0      ...  OFF-ST-6261  Office Supplies      Storage
# 1      ...  OFF-SU-3002  Office Supplies     Supplies
# 2      ...  OFF-ST-6230  Office Supplies      Storage
# 3      ...  OFF-PA-4177  Office Supplies        Paper
# 4      ...  FUR-FU-4075        Furniture  Furnishings
# ...    ...          ...              ...          ...
# 51285  ...  OFF-BI-6397  Office Supplies      Binders
# 51286  ...  OFF-PA-4002  Office Supplies        Paper
# 51287  ...  OFF-LA-4637  Office Supplies       Labels
# 51288  ...  OFF-LA-5388  Office Supplies       Labels
# 51289  ...  OFF-LA-4664  Office Supplies       Labels
#
#                                    Product Name    Sales Quantity Discount  \
# 0                           Tenex Lockers, Blue  408.300        2      0.0
# 1                      Acme Trimmer, High Speed  120.366        3      0.1
# 2                       Tenex Box, Single Width   66.120        4      0.0
# 3                   Enermax Note Cards, Premium   44.865        3      0.5
# 4                    Eldon Light Bulb, Duo Pack  113.670        5      0.1
# ...                                         ...      ...      ...      ...
# 51285   Wilson Jones Hole Reinforcements, Clear    3.990        1      0.0
# 51286                Eaton Note Cards, 8.5 x 11   79.470        3      0.0
# 51287    Hon Color Coded Labels, 5000 Label Set   26.400        3      0.0
# 51288  Novimex Legal Exhibit Labels, Adjustable   16.740        3      0.0
# 51289    Hon Legal Exhibit Labels, Alphabetical    7.120        1      0.0
#
#         Profit  Shipping Cost  Order Priority
# 0      106.140         35.460          Medium
# 1       36.036          9.720          Medium
# 2       29.640          8.170            High
# 3      -26.055          4.820            High
# 4       37.770          4.700          Medium
# ...        ...            ...             ...
# 51285    0.420          1.490          Medium
# 51286   25.380          1.410          Medium
# 51287   12.360          1.350          Medium
# 51288    0.660          1.324          Medium
# 51289    0.560          1.199          Medium
#
# [41296 rows x 24 columns]

# %%
df[df.Sales == 'Shipping Cost']
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Postal Code, City, State, Country, Region, Market, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### Inconsistent Text & Typos
#
# It is represented by vlaues that are either:
# -Incorrect by a few digits or characters
# -Inconsistent with the rest of a column

# %%
df.Profit.describe()
# Out:
# count    51290.000000
# mean        28.610982
# std        174.340972
# min      -6599.978000
# 25%          0.000000
# 50%          9.240000
# 75%         36.810000
# max       8399.976000
# Name: Profit, dtype: float64

# %% [markdown]
# ### Updating Values Based on a Logical Condition

# %%
df.Profit.value_counts()
# Out:
# Profit
#  0.000      668
#  7.920       64
#  3.960       62
#  4.320       60
#  9.000       56
#            ...
#  65.226       1
# -58.380       1
# -37.920       1
# -198.528      1
#  19.791       1
# Name: count, Length: 28234, dtype: int64

# %%
df.Profit = np.where(df.Profit =='Python', 'Intro to Python', df.Profit)
df.Profit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-27797b11473b> in <cell line: 0>()
# ----> 1 df.Profit = np.where(df.Profit =='Python', 'Intro to Python', df.Profit)
#       2 df.Profit
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Map Values

# %%
# map multiple state values to one abbreviation
state_mapping = {'AL': 'AL',
                 'Alabama': 'AL',
                 'NY': 'NY',
                 'New York': 'NY'}

# %%
#use the map method to create a new column
df['State_Clean'] = df.State.map(state_mapping)
df

# %% [markdown]
# ## Time Series (Dates)
#
# Explore our data over time using Order Date

# %%
# Group sales by Year and Month
# creates a new dataframe: monthly_sales
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum().reset_index()
monthly_sales['Order Date'] = monthly_sales['Order Date'].astype(str) # Convert to string for plotting
monthly_sales.head()

# %%
monthly_sales

# %%
monthly_sales.info()

# %%
import matplotlib.pyplot as plt  # Ensure this is included at the top of your code

# Plot the line chart using Matplotlib
plt.figure(figsize=(12,6))
plt.plot(monthly_sales['Order Date'], monthly_sales['Sales'], marker='o', linestyle='-')

# Formatting the plot
plt.title('Sales by Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90) # Rotate x-axis labels for readability
# plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.6)

# Show the plot
plt.show()

# %%
# Create a Sales by Quarter Dataframe
# Group sales data by Year and Quarter
# creates a new dataframe: monthly_sales
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum().reset_index()
monthly_sales['Order Date'] = monthly_sales['Order Date'].astype(str) # Convert to string for plotting
monthly_sales.head()

# %%
# Group sales by Quarter
quarterly_sales = df.groupby(df['Order Date'].dt.to_period('Q'))['Sales'].sum().reset_index()

# Convert 'Order Date' to string for better plotting
quarterly_sales['Order Date'] = quarterly_sales['Order Date'].astype(str)

# Display the first 10 rows
quarterly_sales.head(10)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'Order Date' is a datetime column
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Create a new column for Year-Quarter
df['Year-Quarter'] = df['Order Date'].dt.to_period('Q')

# Group by the 'Year-Quarter' and sum the sales
quarterly_sales = df.groupby('Year-Quarter')['Sales'].sum().reset_index()

# Display the result
print(quarterly_sales)

# %%
import matplotlib.pyplot as plt

# Plot the line chart using Matplotlib
plt.figure(figsize=(12,6))
plt.plot(quarterly_sales['Year-Quarter'].astype(str), quarterly_sales['Sales'], marker='o')

# Formatting the plot
plt.title('Sales by Quarter', fontsize=14)
plt.xlabel('Quarter', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='-', linewidth=0.5, alpha=0.6)

plt.show()

# %% [markdown]
# ## Time Series using the Resample Method

# %%
monthly_sales_rs = df.resample('ME', on='Order Date')['Sales'].sum().reset_index()

# %%
monthly_sales_rs.head(30)

# %%
import matplotlib.pyplot as plt

# Plot the line chart using Matplotlib
plt.figure(figsize=(12,6))
plt.plot(monthly_sales_rs['Order Date'], monthly_sales_rs['Sales'])

# Formatting the plot
plt.title('Sales by Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='-', linewidth=0.5, alpha=0.6)

#Show the plot
plt.show()

# %%
quarterly_sales_rs = df.resample('QE', on='Order Date')['Sales'].sum().reset_index()
quarterly_sales_rs

# %%
import matplotlib.pyplot as plt  # Ensure this is included at the top of your code

# Display Quarterly Sales using Resample
quarterly_sales_rs = df.resample('QE', on='Order Date')['Sales'].sum().reset_index()

# Plot the line chart using Matplotlib
plt.figure(figsize=(12,6))
plt.plot(quarterly_sales_rs['Order Date'], quarterly_sales['Sales'])

# Formatting the plot
plt.title('Sales by Quarter', fontsize=14)
plt.xlabel('Quarter', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90) # Rotate x-axis labels for readability
# plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.6)

# Show the plot
plt.show()
